# %%
import pathlib
import numpy as np
import pandas as pd
import folium

# %%
file_path = 'gwangyang'
p = pathlib.Path(file_path)

# %%
chargingStation = pd.read_csv(p.joinpath('01.광양시_충전기설치현황.csv'))
chargingStation
# Out:
#                  충전소명                                          충전소위치  \
# 0           LF스퀘어 광양점                          전남 광양시 광양읍 순광로 466 1층
# 1         광양만권경제자유구역청                  전남 광양시 광양읍 인덕로 1100(광양시 제2청사)
# 2        광양송보파인빌5차아파트  전남 광양시 진등길 55-5 (마동 송보파인빌류 아파트) 501동~506동 상가동
# 3           광양시 모리스모텔                         전남 광양시 광영로 118-1 지상주차장
# 4          광양시 백운쇼핑센타                            전남 광양시 폭포사랑길 99 주차장
# 5    광양시 블루핸즈(광양정비센터)                       전남 광양시 광양읍 해광로 888 실외주차장
# 6            광양시 비치모텔                        전남 광양시 진월면 백운1로 389 주차장
# 7   광양시 포스코 ICT 광양사업소                             전남 광양시 태인4길 20 주차장
# 8           광양시 프라자모텔                                  전남 광양시 광영로 34
# 9          광양시 광양읍사무소                               전남 광양시 광양읍 남등길 6
# 10        광양시 광영동주민센터                                 전남 광양시 정수2길 47
# 11         광양시 옥곡면사무소                             전남 광양시 옥곡면 옥진로 656
# 12       광양읍사무소 앞 주차장                           전남 광양시 광양읍 칠성리 948-1
# 13          광양주공이차아파트                    전남 광양시 구마9길 11(중동 중마2주공아파트)
# 14           한국전력광양지사                                  전남 광양시 중동로 20
# 15            광영 근린공원                               전남 광양시 광영동 산41-3
# 16          광영동 가야아파트                      전남 광양시 가야로 380(광영동 가야아파트)
# 17          구산칠성이편한세상               전남 광양시 광양읍 서북2길 115(구산리 칠성이편한세상)
# 18       대광로제비앙2차 아파트                       전남 광양시 진등3길 6 지하주차장 B1구역
# 19          대신증권앞 주차장                               전남 광양시 중동 1358-1
# 20               마틴모텔                        전남 광양시 새미골길 8-5 마틴모텔주차장
# 21       섬진강휴게소(부산방향)                         전남 광양시 진월면 섬진강 매화로 141
# 22       섬진강휴게소(부산방향)                         전남 광양시 진월면 섬진강 매화로 141
# 23       섬진강휴게소(순천방향)                           전남 광양시 진월면 신답길 24-14
# 24       섬진강휴게소(순천방향)                           전남 광양시 진월면 신답길 24-14
# 25        쉐보레동광양지점서비스                       전남 광양시 김시식지1길 1-18 외부주차장
# 26             인동숲주차장                       전남 광양시 광양읍 인서리 238 좌측주차장
# 27             인동숲주차장                       전남 광양시 광양읍 인서리 238 좌측주차장
# 28      중마버스터미널 공영주차장                                  전남 광양시 공영로 91
# 29         중마상설시장 주차장                               전남 광양시 주동 1732-3
# 30               호텔자바                            전남 광양시 중동로 98 지하주차장
# 31           홈플러스 광양점                                전남 광양시 항만11로 70
# 32           마동근린체육공원                            전남 광양시 마동 주차장 입구 좌측
# 33         광양중마호반리젠시빌           전남 광양시 공영로 39 실내지하 101103동 사이 지하주차장
# 34         광양중마호반리젠시빌            전남 광양시 공영로 39 실내지하 101103동 사이 지하주차장
# 35           태영1차 아파트            전남 광양시 광장로 112-11 실외노출 101동 관리사무소 앞
# 36           태영2차 아파트               전남 광양시 광장로 120 실외노출 201동 관리사무소 앞
# 37         성호2-1차 아파트              전남 광양시 광장로 70 실내지하 202동 앞 지하1층 우측
# 38       송보파인빌 6차 아파트                       전남 광양시 진등6길 51 정문 604동 앞
# 39       송보파인빌 7차 아파트             전남 광양시 광양읍 와룡길 33 705동 707동 사이 주차장
# 40       송보파인빌 7차 아파트             전남 광양시 광양읍 와룡길 33 705동 707동 사이 주차장
# 41          남해오네뜨 아파트          전남 광양시 광양읍 와룡길 43 실내지하 109동 지하주차장 c15
# 42          남해오네뜨 아파트          전남 광양시 광양읍 와룡길 43 실내지하 109동 지하주차장 c15
# 43       광양읍 목성 주공아파트                전남 광양시 신재로 82 실외노출 관리사무소 뒷편 주차장
#
#           충전기 운영기관 급속/완속       충전기용량  이용대수            충전기타입  요금정보(원/kw)  \
# 0   환경부(한국자동차환경협회)    급속  200KW 동시충전     2             DC콤보      255.70
# 1   환경부(한국자동차환경협회)    급속        50KW     1  DC차데모/AC3상/DC콤보      255.70
# 2              케이티    완속       7kw/h     5             AC완속      170.00
# 3              차지비    완속       7kw/h     2             AC완속      250.00
# 4              차지비    완속       7kw/h     2             AC완속      245.00
# 5              차지비    완속       7kw/h     1             AC완속      245.00
# 6              차지비    완속       7kw/h     2             AC완속      250.00
# 7              차지비    완속       7kw/h     1             AC완속      250.00
# 8              차지비    완속       7kw/h     2             AC완속      250.00
# 9       한국전기차충전서비스    완속       7kw/h     1             AC완속      255.70
# 10      한국전기차충전서비스    완속       7kw/h     1             AC완속      255.70
# 11      한국전기차충전서비스    완속       7kw/h     1             AC완속      255.70
# 12  환경부(한국자동차환경협회)    급속  200KW 동시충전     2             DC콤보      255.70
# 13             케이티    완속       7kw/h     1             AC완속      170.00
# 14            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 15            한국전력    급속         NaN     2  DC차데모/AC3상/DC콤보      191.73
# 16             케이티    완속       7kw/h     4             AC완속      170.00
# 17             케이티    완속       7kw/h     2             AC완속      170.00
# 18             케이티    완속       7kw/h     3             AC완속      170.00
# 19  환경부(한국자동차환경협회)    급속  200KW 동시충전     2             DC콤보      255.70
# 20      한국전기차충전서비스    완속       7kw/h     2             AC완속      255.70
# 21  환경부(한국자동차환경협회)    급속        50KW     1  DC차데모/AC3상/DC콤보      255.70
# 22  환경부(한국자동차환경협회)    급속      100KW      1  DC차데모/AC3상/DC콤보      255.70
# 23  환경부(한국자동차환경협회)    급속       100KW     1  DC차데모/AC3상/DC콤보      255.70
# 24  환경부(한국자동차환경협회)    급속        50KW     1  DC차데모/AC3상/DC콤보      255.70
# 25      한국전기차충전서비스    완속       7kw/h     1             AC완속      255.70
# 26  환경부(한국자동차환경협회)    급속        50KW     1  DC차데모/AC3상/DC콤보      255.70
# 27  환경부(한국자동차환경협회)    급속  100KW 동시충전     2             DC콤보      255.70
# 28  환경부(한국자동차환경협회)    급속        50KW     1  DC차데모/AC3상/DC콤보      255.70
# 29  환경부(한국자동차환경협회)    급속  200KW 동시충전     2             DC콤보      255.70
# 30      한국전기차충전서비스    완속       7kw/h     2             AC완속      255.70
# 31            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 32            한국전력    급속         NaN     2  DC차데모/AC3상/DC콤보      191.73
# 33            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 34            한국전력    완속       7kw/h     3             AC완속      191.73
# 35            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 36            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 37            한국전력    급속         NaN     2  DC차데모/AC3상/DC콤보      191.73
# 38            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 39            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 40            한국전력    완속       7kw/h     2             AC완속      191.73
# 41            한국전력    급속         NaN     1  DC차데모/AC3상/DC콤보      191.73
# 42            한국전력    완속       7kw/h     3             AC완속      191.73
# 43            한국전력    완속       7kw/h     2             AC완속      191.73
#
#            lon        lat
# 0   127.568300  34.963002
# 1   127.583323  34.980334
# 2   127.689013  34.953759
# 3   127.716708  34.964032
# 4   127.732440  34.940444
# 5   127.582443  34.963334
# 6   127.750981  34.962506
# 7   127.760072  34.941198
# 8   127.725127  34.962147
# 9   127.580612  34.973057
# 10  127.721913  34.962806
# 11  127.699053  34.989479
# 12  127.580523  34.972300
# 13  127.685670  34.944650
# 14  127.691011  34.940027
# 15  127.718854  34.960699
# 16  127.714850  34.966210
# 17  127.576134  34.974887
# 18  127.688809  34.952244
# 19  127.694421  34.942039
# 20  127.723417  34.962668
# 21  127.770993  34.984890
# 22  127.770993  34.984890
# 23  127.768300  34.984695
# 24  127.768300  34.984695
# 25  127.758109  34.946130
# 26  127.587542  34.970164
# 27  127.587542  34.970164
# 28  127.698619  34.936225
# 29  127.699739  34.938525
# 30  127.699228  34.941020
# 31  127.694138  34.928488
# 32  127.692320  34.952065
# 33  127.692992  34.936355
# 34  127.692992  34.936355
# 35  127.697259  34.934237
# 36  127.695222  34.934223
# 37  127.690686  34.933274
# 38  127.691866  34.956315
# 39  127.612698  34.970095
# 40  127.612698  34.970095
# 41  127.610457  34.968399
# 42  127.610457  34.968399
# 43  127.591137  34.978306

# %%
parkingLot = pd.read_csv(p.joinpath('02.광양시_주차장_공간정보.csv'))
parkingLot
# Out:
#         주차장명칭   구분      면적   주차면수 유료/무료          주소         lon        lat
# 0    인동숲앞 주차장   노외  4189.0  161.0    유료   인서리 237-1  127.586883  34.970324
# 1     구터미널주차장   노외  2968.0  125.0    유료     중동 1651  127.695428  34.936252
# 2    구경찰서 주차장   노외  2836.0   89.0    무료   읍내리 227-1  127.584586  34.975637
# 3       칠성1지구   노외  1980.0   52.0    무료   칠성리 962-1  127.580683  34.970130
# 4       칠성1지구   노외  1970.0   64.0    무료   칠성리 948-1  127.580707  34.972523
# ..        ...  ...     ...    ...   ...         ...         ...        ...
# 230   포석정위도로변  피서지   264.0   10.0    무료   동곡리 662-1  127.604822  35.079214
# 231     동곡산장옆  피서지  1212.0   60.0    무료     동곡리 549  127.613417  35.070673
# 232     하천첨주변  피서지  2381.0   96.0    무료   산남리 154-4  127.611774  35.002759
# 233      회계분교  피서지  2090.0   66.0    무료  진상 어치 1140  127.674719  35.092388
# 234    회두마을입구  피서지   827.0   30.0    무료   진상 어치 914  127.676139  35.090000
#
# [235 rows x 8 columns]

# %%
campsite = pd.read_csv(p.joinpath('05.광양시_대중집합시설_야영장.csv'))
campsite
# Out:
#           명칭                   주소 소유주체(공공/민간)         lon        lat
# 0    진틀펜션야영장  광양시 옥룡면 신재로 1678-54          민간  127.601787  35.096566
# 1  느랭이골자연휴양림  광양시 다압면 토끼재길 119-32          민간  127.710849  35.060546
# 2  백운산수련관야영장    광양시 옥룡면 약수제단길 154          민간  127.631555  35.069553
# 3  봉강하조오토캠핑장     광양시 봉강면 성불로 1097          민간  127.562487  35.076193
# 4   백운산자연휴양림      광양시 옥룡면 백계로 337          공공  127.591184  35.054216
# 5   백운제오토캠핑장      광양시 봉강면 봉당리 178          공공  127.581644  35.005226

# %%
m = folium.Map([lat,lon], zoom_start=11)

for i in chargingStation.index:
    cs_lat = chargingStation.loc[i,"lat"]
    cs_lon = chargingStation.loc[i,'lon']
    title = chargingStation.loc[i,"충전소명"] + " - " + chargingStation.loc[i,"충전소위치"]
    
    folium.Marker([cs_lat, cs_lon],icon=folium.Icon(color='blue'), tooltip=title).add_to(m)
m

for i in parkingLot.index:
    pl_lat = parkingLot.loc[i,"lat"]
    pl_lon = parkingLot.loc[i,'lon']
    title = parkingLot.loc[i,"주차장명칭"] + " - " + parkingLot.loc[i,"주소"]
    
    folium.Marker([pl_lat, pl_lon], icon=folium.Icon(color='darkpurple'), tooltip=title).add_to(m)
m

for i in campsite.index:
    cp_lat = campsite.loc[i,"lat"]
    cp_lon = campsite.loc[i,'lon']
    title = campsite.loc[i,"명칭"] + " - " + campsite.loc[i,"주소"]
    
    folium.Marker([cp_lat, cp_lon], icon=folium.Icon(color='lightgreen'), tooltip=title).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
